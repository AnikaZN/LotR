# %%
import pandas as pd

df = pd.read_csv('./lotr_with_name_info.csv')
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1)

# %%
df.columns
# Out:
# Index(['birth', 'death', 'gender', 'hair', 'height', 'name', 'race', 'realm',
#        'spouse', 'name_length', 'vowel_count', 'pct_vowels', 'first_letter',
#        'starts_vowel'],
#       dtype='object')

# %%
pd.options.display.max_rows = 1000
df['birth'].unique

# Unknown
# Before the creation of Arda
# c. 0-5000 Creation of Arda
# c. 5000-10000 Years of the Lamps
# c. 10000-30000 Years of the Trees
# c. 30000+ Years of the Sun
# # # First Age 0-587
# # # Second Age 0-3441
# # # Third Age 0-3021
# # # Fourth Age 0-250
# Out:
# <bound method Series.unique of 0      NaN
# 1      TA 2978
# 2      NaN
# 3      TA 280
# 4      NaN
# 5      SA 2709
# 6      NaN
# 7      YT
# 8      NaN
# 9      SA 3219
# 10     SA 3118
# 11     SA 2876
# 12     SA 2960
# 13     TA 2866
# 14     NaN
# 15     Late ,Third Age
# 16     Perhaps ,Firstborn
# 17     NaN
# 18     NaN
# 19     NaN
# 20     Early ,First Age
# 21     TA 654
# 22     SA 2277
# 23     SA 1320
# 24     SA 2136
# 25     SA 1174
# 26     SA 3035
# 27     SA 3117
# 28     SA 1474
# 29     SA 350
# 30     SA 2516
# 31     SA 1800
# 32     SA 543
# 33     SA 2618
# 34     SA 1634
# 35     SA 1003
# 36     SA 873
# 37     SA 1986
# 38     SA 192
# 39     SA 2406
# 40     NaN
# 41     TA 2922
# 42     NaN
# 43     SA 799
# 44     SA 700
# 45     YT, and perhaps Firstborn
# 46     YT 1300
# 47     YT during the ,Noontide of Valinor
# 48     YT 1190
# 49     TA 2950
# 50     First Age
# 51     Years of the Trees
# 52     Fourth Age
# 53     YT 1230
# 54     NaN
# ...

# %%
df['death'].unique

# Unknown
# Immortal
# Still Alive
# # # First Age 0-587
# # # Second Age 0-3441
# # # Third Age 0-3021
# # # Fourth Age 0-250
# Out:
# <bound method Series.unique of 0      NaN
# 1      February 26 ,3019
# 2      March ,3019
# 3      TA 515
# 4      NaN
# 5      SA 2962
# 6      NaN
# 7      FA 455
# 8      NaN
# 9      SA 3440
# 10     Still alive
# 11     SA 3102
# 12     SA 3177
# 13     TA 2977
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     FA 510
# 20     NaN
# 21     TA 913
# 22     SA 2637
# 23     SA 1731
# 24     SA 2526
# 25     SA 1574
# 26     SA 3255
# 27     SA 3319
# 28     SA 1873
# 29     SA 751
# 30     SA 2825
# 31     SA 2221
# 32     SA 942
# 33     SA 2899
# 34     SA 2035
# 35     SA 1404
# 36     SA 1285
# 37     SA 2386
# 38     SA 603
# 39     SA 2737
# 40     NaN
# 41     NaN
# 42     NaN
# 43     Early ,Second Age
# 44     SA 1098
# 45     YT 1495
# 46     FA 465
# 47     FA 472
# 48     FA 455
# 49     TA 2988
# 50     FA 495
# 51     NaN
# 52     sometime after ,FO 172
# 53     Still Alive
# 54     NaN
# 55     TA 2801
# 56     Early ,Fourth Age
# ...

# %%
df['spouse'].value_counts()
# Out:
# Unnamed wife                                             237
# None                                                     43
# None known                                               3
# Unknown, possibly none                                   3
# Unnamed wife                                             2
# Possibly none                                            2
# Unnamed Wife                                             2
# unknown                                                  2
# Vairë                                                    2
# Possible unnamed wife                                    2
# Belba Baggins                                            2
# Unknown, possibly known                                  2
# Lavender Grubb                                           2
# Finwë                                                    2
# Unnamed husband                                          2
# Meldis                                                   1
# ...
